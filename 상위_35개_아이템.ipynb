# %% [markdown]
# <a href="https://colab.research.google.com/github/bellacitrine/minji/blob/minji/%EC%83%81%EC%9C%84_35%EA%B0%9C_%EC%95%84%EC%9D%B4%ED%85%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/챔피언-장착 아이템 테이블.csv')

# %%
df.head()
# Out:
#           gameId  game_datetime  game_length  \
# 0  KR_7005474854   1.711610e+12  2212.314209
# 1  KR_7005474854   1.711610e+12  2212.314209
# 2  KR_7005474854   1.711610e+12  2212.314209
# 3  KR_7005474854   1.711610e+12  2212.314209
# 4  KR_7005474854   1.711610e+12  2212.314209
#
#                                         game_version  \
# 0  Version 14.6.570.6276 (Mar 25 2024/14:00:15) [...
# 1  Version 14.6.570.6276 (Mar 25 2024/14:00:15) [...
# 2  Version 14.6.570.6276 (Mar 25 2024/14:00:15) [...
# 3  Version 14.6.570.6276 (Mar 25 2024/14:00:15) [...
# 4  Version 14.6.570.6276 (Mar 25 2024/14:00:15) [...
#
#                                                puuid  placement  last_round  \
# 0  _8i48hZ4TO6IqpIYvh1AcQwTd946qLfAfwIDRSMf4sd0vs...          1          37
# 1  _8i48hZ4TO6IqpIYvh1AcQwTd946qLfAfwIDRSMf4sd0vs...          1          37
# 2  _8i48hZ4TO6IqpIYvh1AcQwTd946qLfAfwIDRSMf4sd0vs...          1          37
# ...

# %%
df = df.drop(['gameId', 'game_datetime', 'game_length',	'game_version',	'puuid', 'last_round', 'level',
              'character_id', 'itemNames', 'tiers', 'item1', 'item2', 'item3', 'itemNames_str'], axis=1)

# %%
df
# Out:
#        placement   챔피언     아이템1     아이템2     아이템3
# 0              1  다이애나      NaN      NaN      NaN
# 1              1   갈리오  가고일 돌갑옷  태양불꽃 망토   도적의 장갑
# 2              1   흐웨이   보석 건틀릿   내셔의 이빨    쇼진의 창
# 3              1    케일   지원의 부적      NaN      NaN
# 4              1   릴리아   푸른 파수꾼  붉은 덩굴정령   정의의 손길
# ...          ...   ...      ...      ...      ...
# 82380          1    오른    덤불 조끼    용의 발톱  워모그의 갑옷
# 82381          1    라칸      NaN      NaN      NaN
# 82382          1   소라카      NaN      NaN      NaN
# 82383          1   우디르   쇠사슬 조끼      NaN      NaN
# 82384          1    오공   거인의 결의   거인의 결의      NaN
#
# [82385 rows x 5 columns]

# %%
df.replace({'B.F. 대검':'NaN', '강철의 솔라리 펜던트':'NaN', '거대 괴수 상징':'NaN', '거물의 갑옷':'NaN', '거석상의 유산':'NaN',
           '거인의 맹세':'NaN', '거인의 허리띠':'NaN', '결투가 상징':'NaN', '곡궁':'NaN', '공범의 장갑':'NaN', '도적의 장갑':'NaN',
           '공정의 주먹':'NaN', '구인수의 심판':'NaN', '군단의 방패':'NaN', '기원자 상징':'NaN', '난동꾼 상징':'NaN',
           '남작의 선물':'NaN', '눈부신 건틀릿':'NaN', '다이아몬드 손':'NaN', '대장장이의 장갑':'NaN', '도박꾼의 칼날':'NaN',
           '도자기 상징':'NaN', '독의 문신':'NaN', '뒤집개':'NaN', '라바돈의 초월한 죽음모자':'NaN', '란두인의 예언':'NaN',
           '루난의 폭풍':'NaN', '마나자네':'NaN', '마법공학 생명검':'NaN', '먹그림자 상징':'NaN', '면죄':'NaN', '무력의 부적':'NaN',
           '무한한 삼위일체':'NaN', '반짝이는 수은':'NaN', '밴시의 장막':'NaN', '별의 균형':'NaN', '보호의 문신':'NaN',
           '분노의 문신':'NaN', '비전 마법사 상징':'NaN', '빛나는 죽음의 검':'NaN', '사신 상징':'NaN', '새벽의 서광':'NaN',
           '서풍':'NaN', '선체분쇄자':'NaN', '속도의 부적':'NaN', '속임수 거울':'NaN', '쇠사슬 조끼':'NaN', '수호상 돌갑옷':'NaN',
           '순교자의 미덕':'NaN', '숲지기 상징':'NaN', '스태틱의 호의':'NaN', '스테락의 초강력 보호막':'NaN', '신화 상징':'NaN',
           '쓸데없이 큰 보석':'NaN', '쓸데없이 큰 지팡이':'NaN', '악마 학살자':'NaN', '암영 상징':'NaN', '엔젤로노미콘':'NaN',
           '여신의 눈물':'NaN', '연습용 장갑':'NaN', '영겁의 속삭임':'NaN', '영원한 겨울':'NaN', '영혼의 형상':'NaN', '왕가의 방패':'NaN',
           '용군주 상징':'NaN', '용의 의지':'NaN', '우르프 천사의 지팡이':'NaN', '워모그의 자부심':'NaN', '음전자 망토':'NaN',
           '의지파괴자':'NaN', '이야기꾼 상징':'NaN', '이타심 상징':'NaN', '잉걸불 문장':'NaN', '장난꾸러기의 장갑':'NaN',
           '장미가시 조끼':'NaN', '저격수 상징':'NaN', '저격수의 집중':'NaN', '전략가의 왕관':'NaN', '존야의 역설':'NaN',
           '죽음불꽃 손아귀':'NaN', '죽음의 저항':'NaN', '즈롯 차원문':'NaN', '지원의 부적':'NaN', '지크의 전령':'NaN',
           '집단 충격기':'NaN', '천계 상징':'NaN', '천공의 대검':'NaN', '철갑의 서약':'NaN', '축복받은 피바라기':'NaN',
           '침묵의 장막':'NaN', '태양빛 망토':'NaN', '파수꾼 상징':'NaN', '폭격의 문신':'NaN', '푸른 축복':'NaN', '필연 상징':'NaN',
           '해신 작쇼':'NaN', '행운 상징':'NaN', '현자 상징':'NaN', '혼령 상징':'NaN', '활력의 문신':'NaN', '황금 징수의 총':'NaN',
           '황금술사의 지팡이':'NaN', '흑요석 양날 도끼':'NaN', '히라나의 창':'NaN', '힘의 문신':'NaN', '힘의 성배':'NaN'})
# Out:
#        placement   챔피언     아이템1     아이템2     아이템3
# 0              1  다이애나      NaN      NaN      NaN
# 1              1   갈리오  가고일 돌갑옷  태양불꽃 망토      NaN
# 2              1   흐웨이   보석 건틀릿   내셔의 이빨    쇼진의 창
# 3              1    케일      NaN      NaN      NaN
# 4              1   릴리아   푸른 파수꾼  붉은 덩굴정령   정의의 손길
# ...          ...   ...      ...      ...      ...
# 82380          1    오른    덤불 조끼    용의 발톱  워모그의 갑옷
# 82381          1    라칸      NaN      NaN      NaN
# 82382          1   소라카      NaN      NaN      NaN
# 82383          1   우디르      NaN      NaN      NaN
# 82384          1    오공   거인의 결의   거인의 결의      NaN
#
# [82385 rows x 5 columns]

# %%
df.to_csv('상위 35개 아이템.csv', header=True, index=False, encoding='utf8')
